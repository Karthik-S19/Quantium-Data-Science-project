# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv("QVI_data.csv");

# %%
data.head()
# Out:
#    LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0            1000  2018-10-17          1       1         5
# 1            1002  2018-09-16          1       2        58
# 2            1003  2019-03-07          1       3        52
# 3            1003  2019-03-08          1       4       106
# 4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0        175
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7        150
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6        210
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0        175
# 4          WW Original Stacked Chips 160g         1        1.9        160
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0     NATURAL  YOUNG SINGLES/COUPLES          Premium
# 1         RRD  YOUNG SINGLES/COUPLES       Mainstream
# ...

# %%
store77=data[data['STORE_NBR']==77]
store77.reset_index(drop=True, inplace=True)
store77
# Out:
#      LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0             77000  2019-03-28         77   74911        18
# 1             77000  2019-04-13         77   74912        69
# 2             77000  2018-09-26         77   74910        36
# 3             77001  2019-02-27         77   74913         7
# 4             77001  2019-01-21         77   74914         9
# ..              ...         ...        ...     ...       ...
# 558         2330321  2018-07-30         77  236756        71
# 559         2330331  2018-11-18         77  236760        95
# 560         2330431  2018-07-31         77  236770        50
# 561         2330461  2018-07-21         77  236777        87
# 562         2330501  2019-06-20         77  236780        63
#
#                                     PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0              Cheetos Chs & Bacon Balls 190g         1        3.3        190
# ...

# %% [raw]
# import math

# %%
import math

# %%
TOT_SALES77 = store77['TOT_SALES'].sum()
print(TOT_SALES77)
# Out:
# 3040.0

# %%
Total_Customers_77 = len(store77['LYLTY_CARD_NBR'].value_counts())

# %%
Total_Customers_77
# Out:
# 356

# %%
print(store77['TXN_ID'].value_counts())
# Out:
# TXN_ID
# 75395     2
# 74911     1
# 75285     1
# 75284     1
# 75287     1
#          ..
# 75094     1
# 75093     1
# 75090     1
# 75092     1
# 236780    1
# Name: count, Length: 562, dtype: int64

# %%
Average_No_Of_Transactions_per_customer_77 = 562/356

# %%
print(Average_No_Of_Transactions_per_customer_77)
# Out:
# 1.5786516853932584

# %%
store86=data[data['STORE_NBR']==86]
store86.reset_index(drop=True, inplace=True)
store86
# Out:
#       LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0              86000  2018-08-26         86   84137        90
# 1              86000  2018-09-25         86   84138        88
# 2              86000  2019-02-19         86   84139        41
# 3              86000  2018-11-20         86   84140       111
# 4              86000  2018-11-30         86   84141        13
# ...              ...         ...        ...     ...       ...
# 1533          155479  2018-08-19         86  155508        74
# 1534          155479  2018-11-21         86  155509         9
# 1535          155485  2018-11-08         86  155552        97
# 1536          155489  2018-08-15         86  155582        78
# 1537          155510  2018-08-14         86  155718        82
#
#                                     PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0           Tostitos Smoked     Chipotle 175g         2        8.8        175
# ...

# %%
TOT_SALES86 = store86['TOT_SALES'].sum()
print(TOT_SALES86)
# Out:
# 10635.35

# %%
Total_Customers_86 = len(store86['LYLTY_CARD_NBR'].value_counts())

# %%
Total_Customers_86
# Out:
# 273

# %%
print(store86['TXN_ID'].value_counts())
# Out:
# TXN_ID
# 85074     2
# 84832     2
# 85187     2
# 84707     2
# 84649     2
#          ..
# 84661     1
# 84660     1
# 84659     1
# 84658     1
# 155718    1
# Name: count, Length: 1526, dtype: int64

# %%
Average_No_Of_Transactions_per_customer_86 = 1526/273

# %%
print(Average_No_Of_Transactions_per_customer_86)
# Out:
# 5.589743589743589

# %%
store88=data[data['STORE_NBR']==88]
store88.reset_index(drop=True, inplace=True)
store88
# Out:
#       LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0              88000  2018-09-12         88   86220         4
# 1              88000  2018-10-26         88   86221        31
# 2              88000  2019-02-02         88   86222        46
# 3              88000  2019-05-01         88   86223        47
# 4              88000  2019-05-02         88   86224       102
# ...              ...         ...        ...     ...       ...
# 1868         2370701  2018-12-08         88  240378        24
# 1869         2370751  2018-10-01         88  240394        60
# 1870         2370961  2018-10-24         88  240480        70
# 1871         2370961  2018-10-27         88  240481        65
# 1872         2373711  2018-12-14         88  241815        16
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES  \
# 0             Dorito Corn Chp     Supreme 380g         2       13.0
# 1       Infzns Crn Crnchers Tangy Gcamole 110g         2        7.6
# ...

# %%
TOT_SALES88 = store88['TOT_SALES'].sum()
print(TOT_SALES88)
# Out:
# 16333.25

# %%
Total_Customers_88 = len(store88['LYLTY_CARD_NBR'].value_counts())

# %%
Total_Customers_88
# Out:
# 388

# %%
print(store88['TXN_ID'].value_counts())
# Out:
# TXN_ID
# 86238     2
# 86657     2
# 87415     2
# 86954     2
# 87259     2
#          ..
# 86858     1
# 86857     1
# 86856     1
# 86855     1
# 241815    1
# Name: count, Length: 1857, dtype: int64

# %%
Average_No_Of_Transactions_per_customer_88 = 1857/388

# %%
print(Average_No_Of_Transactions_per_customer_88)
# Out:
# 4.786082474226804
